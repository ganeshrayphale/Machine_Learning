# %%
from sklearn.datasets import load_diabetes
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv('adult.csv')

# %%
df.sample(5)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 9247    23           Private  305423     Bachelors               13
# 36489   33      Self-emp-inc  144949     Bachelors               13
# 45775   39         State-gov  142897     Assoc-voc               11
# 22067   43           Private  361280          10th                6
# 45256   38  Self-emp-not-inc  172342  Some-college               10
#
#            marital-status         occupation relationship                race  \
# 9247        Never-married  Handlers-cleaners    Own-child               White
# 36489  Married-civ-spouse              Sales      Husband               White
# 45775       Never-married    Exec-managerial    Unmarried               White
# 22067  Married-civ-spouse       Craft-repair      Husband  Asian-Pac-Islander
# 45256            Divorced      Other-service    Unmarried               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# ...

# %%
drop_coulumns=['fnlwgt','education']

# %%
df=df.drop(columns=drop_coulumns)

# %%
df
# Out:
#        age     workclass  educational-num      marital-status  \
# 0       25       Private                7       Never-married
# 1       38       Private                9  Married-civ-spouse
# 2       28     Local-gov               12  Married-civ-spouse
# 3       44       Private               10  Married-civ-spouse
# 4       18             ?               10       Never-married
# ...    ...           ...              ...                 ...
# 48837   27       Private               12  Married-civ-spouse
# 48838   40       Private                9  Married-civ-spouse
# 48839   58       Private                9             Widowed
# 48840   22       Private                9       Never-married
# 48841   52  Self-emp-inc                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# ...

# %%
df.sample()
# Out:
#        age  workclass  educational-num marital-status    occupation  \
# 42486   18  State-gov                9  Never-married  Adm-clerical
#
#       relationship   race gender  capital-gain  capital-loss  hours-per-week  \
# 42486    Own-child  Black   Male             0             0              15
#
#       native-country income
# 42486  United-States  <=50K

# %%
df.value_counts(['workclass'])
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df = df[df['workclass'] != '?']

# %%
df.value_counts(['workclass'])
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['workclass']=pd.get_dummies(df['workclass'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df['workclass']=pd.get_dummies(df['workclass'],drop_first=True)
#
# File c:\Users\rayph\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4662, in DataFrame.__setitem__(self, key, value)
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
# -> 4662             self._set_item_frame_value(key, value)
#    4663         elif (
#    4664             is_list_like(value)
#    4665             and not self.columns.is_unique
#
# File c:\Users\rayph\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4786, in DataFrame._set_item_frame_value(self, key, value)
# ...

# %%
x=df.iloc[:,:12]
y=df.iloc[:,12:13]

# %%
y.sample(5)
# Out:
#       income
# 356    <=50K
# 1024   <=50K
# 29967  <=50K
# 4055   <=50K
# 12463   >50K

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y,random_state=42,test_size=0.25
)

# %%
regressor=DecisionTreeRegressor(max_depth=None)
regressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 regressor=DecisionTreeRegressor(max_depth=None)
# ----> 2 regressor.fit(x_train,y_train)
#
# File c:\Users\rayph\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\rayph\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\tree\_classes.py:1407, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1377 @_fit_context(prefer_skip_nested_validation=True)
# ...
