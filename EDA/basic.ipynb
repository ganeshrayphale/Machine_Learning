# %%
import pandas as pd

# %%
df=pd.read_csv('india_evcharging.csv')

# %%
df.shape
# Out:
# (171, 11)

# %%
df.sample(5)
# Out:
#      Unnamed: 0                         name  \
# 40           40        BPCL Charging Station
# 93           93              Ankush Vehicles
# 160         160     Tata EV charging station
# 137         137  Ather Grid Charging Station
# 124         124       Adani Charging Station
#
#                                             connectors  \
# 40   [{'type': 'CCS', 'total': 2, 'available': 1, '...
# 93                                                  []
# 160                                                 []
# 137  [{'type': 'LECCS', 'total': 1, 'available': 1,...
# 124  [{'type': 'Type 2', 'total': 2, 'available': 0...
#
#                                      formatted_address  \
# 40   JWMG+MWC, RO AT DAHEGAON, Mahar, Nagpur, Wardh...
# 93                                 Chhattisgarh 495690
# 160  1/469/24, VGP MANGALPURI TOWN POOMALUR, Tirupp...
# 137  Dhabha Toll Tax, near, Katol Bypass Rd, Wadi, ...
# 124  No. 59/1, Forest Gatesv, Mohurli, 60/1, near M...
#
# ...

# %%
df.isnull().count()
# Out:
# Unnamed: 0            171
# name                  171
# connectors            171
# formatted_address     171
# address_components    171
# latitude              171
# longitude             171
# place_link            171
# phone_number          171
# rating                171
# review_count          171
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0    latitude   longitude  phone_number      rating  \
# count  171.000000  171.000000  171.000000  2.000000e+00  104.000000
# mean    85.000000   21.136435   80.649060  1.888334e+10    3.636538
# std     49.507575    0.329499    1.571167  0.000000e+00    1.290372
# min      0.000000   20.088792   78.476983  1.888334e+10    1.000000
# 25%     42.500000   21.042628   79.044471  1.888334e+10    3.000000
# 50%     85.000000   21.147218   81.585515  1.888334e+10    3.750000
# 75%    127.500000   21.243997   81.691613  1.888334e+10    5.000000
# max    170.000000   22.046612   83.944182  1.888334e+10    5.000000
#
#        review_count
# count    171.000000
# mean       2.701754
# std        6.703726
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max       76.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          171 non-null    int64
#  1   name                171 non-null    object
#  2   connectors          171 non-null    object
#  3   formatted_address   171 non-null    object
#  4   address_components  171 non-null    object
#  5   latitude            171 non-null    float64
#  6   longitude           171 non-null    float64
#  7   place_link          171 non-null    object
#  8   phone_number        2 non-null      float64
#  9   rating              104 non-null    float64
#  10  review_count        171 non-null    int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 14.8+ KB

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.corr()
#
# File c:\Users\rayph\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\rayph\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
# ...
