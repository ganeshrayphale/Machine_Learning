# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# C:\Users\rayph\AppData\Local\Temp\ipykernel_27292\3034448462.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
df2=pd.read_csv('heart.csv')

# %%
df2.sample(4)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 792   46   M           NAP        150          231          0     Normal
# 831   63   F           NAP        135          252          0        LVH
# 56    31   M           ASY        120          270          0     Normal
# 328   52   M           ASY         95            0          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 792    147              N      3.6     Flat             1
# 831    172              N      0.0       Up             0
# 56     153              Y      1.5     Flat             1
# 328     82              Y      0.8     Flat             1

# %%
prof=ProfileReport(df2)
prof.to_file(output_file='deepanalysis.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
